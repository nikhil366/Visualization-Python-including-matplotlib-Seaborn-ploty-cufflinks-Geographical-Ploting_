# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns

# %%
'''time series we can use to measure or to observe data according to time for example stock market
via the time series and line plot we can measure the data when it grow and when it decrease'''
df1 = pd.read_csv('df1', index_col=0)
df1.head()
# here in df1 we use or apply time series
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %%
# ploting a histogram 
df1['A'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
 # changing a number of bins
 df1['A'].plot(kind='hist', bins = 30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# ploting a area
df2.plot.area()
# Out:
# <AxesSubplot:>

# %%
df2.describe()
# Out:
#                a          b          c          d
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.460880   0.352935   0.587008   0.631597
# std     0.340793   0.301272   0.284332   0.258158
# min     0.039762   0.008948   0.103423   0.190008
# 25%     0.212334   0.179302   0.427949   0.457694
# 50%     0.371366   0.240298   0.555036   0.584144
# 75%     0.753558   0.515799   0.873619   0.837267
# max     0.937288   0.997075   0.907307   0.977680

# %% [markdown]
# ## Barplot

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
# implement stacked
df2.plot.bar(stacked = True)
# Out:
# <AxesSubplot:>

# %%
df1.plot.scatter(x = 'A',y = 'B',c = 'C', cmap = 'coolwarm')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.box()
# Out:
# <AxesSubplot:>

# %%
np.random.randn(1000,2)
# Out:
# array([[-0.46145763,  1.1744504 ],
#        [-1.25578388,  0.15259718],
#        [-0.27131572,  1.30343095],
#        ...,
#        [-0.45163385,  1.1655812 ],
#        [-0.87259899, -0.77044633],
#        [ 1.14675697,  0.38000082]])
